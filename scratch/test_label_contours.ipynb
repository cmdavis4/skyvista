# %%
import pyvista as pv

# %%
pv.examples.load_frog_tissues()
# Out:
# ImageData (0x7f54caac09a0)
#   N Cells:      31594185
#   N Points:     31960000
#   X Bounds:     0.000e+00, 4.990e+02
#   Y Bounds:     0.000e+00, 4.690e+02
#   Z Bounds:     0.000e+00, 2.025e+02
#   Dimensions:   500, 470, 136
#   Spacing:      1.000e+00, 1.000e+00, 1.500e+00
#   N Arrays:     1

# %%
pv.examples.load_channels()
# Out:
# ImageData (0x7f54caac0ca0)
#   N Cells:      6250000
#   N Points:     6363101
#   X Bounds:     0.000e+00, 2.500e+02
#   Y Bounds:     0.000e+00, 2.500e+02
#   Z Bounds:     0.000e+00, 1.000e+02
#   Dimensions:   251, 251, 101
#   Spacing:      1.000e+00, 1.000e+00, 1.000e+00
#   N Arrays:     1
